# %%
# Netflx data analysis

# %% [markdown]
# ### Loading and Inspection

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# load the data 
df = pd.read_csv('netflix_sample_data.csv')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# tail -> last 5 rows
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# check shape of data 
df.shape
# Out:
# (8807, 12)

# %%
# check columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
# view info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# check missing values 
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# detect duplicate 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# change index from default 1,2,3 to show id 
df.set_index('show_id',inplace=True)

# %%
# sort by release_yes
# two latest movies
df.sort_values('release_year',ascending=False).head(2)
# Out:
#             type          title         director  \
# show_id
# s2       TV Show  Blood & Water              NaN
# s3       TV Show      Ganglands  Julien Leclercq
#
#                                                       cast       country  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
#
#                                                  listed_in  \
# show_id
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
#
#                                                description
# show_id
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...

# %%
df.tail()
# Out:
#             type        title         director  \
# show_id
# s8803      Movie       Zodiac    David Fincher
# s8804    TV Show  Zombie Dumb              NaN
# s8805      Movie   Zombieland  Ruben Fleischer
# s8806      Movie         Zoom     Peter Hewitt
# s8807      Movie       Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                 date_added  release_year rating   duration  \
# show_id
# s8803    November 20, 2019          2007      R    158 min
# s8804         July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# there are many columns values with Nan 
# chnage Nan->Unknown
# fillin director 
df['director'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11956\3500051706.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna('Unknown',inplace=True)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
# now same as 
#cast
df['cast'].fillna('Unknown', inplace=True)
#country
df['country'].fillna('Unknown', inplace=True)
# data_added
df['date_added'].fillna('Unknown', inplace=True)
# rating
df['rating'].fillna('Not Rated', inplace=True)
# duration 
df['duration'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11956\1673895854.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna('Unknown', inplace=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_11956\1673895854.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
# strip white space -> 
df['title'] = df['title'].str.strip()
df['title']
# Out:
# show_id
# s1        Dick Johnson Is Dead
# s2               Blood & Water
# s3                   Ganglands
# s4       Jailbirds New Orleans
# s5                Kota Factory
#                  ...
# s8803                   Zodiac
# s8804              Zombie Dumb
# s8805               Zombieland
# s8806                     Zoom
# s8807                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
# title to lower case 
df['title'] = df['title'].str.lower()

# %%
df['rating'] = df['rating'].replace({'UR': 'R', 'NR': 'Not Rated'})

# %%
df = df[df['release_year'] >= 1900]

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   dick johnson is dead  Kirsten Johnson
# s2       TV Show          blood & water          Unknown
# s3       TV Show              ganglands  Julien Leclercq
# s4       TV Show  jailbirds new orleans          Unknown
# s5       TV Show           kota factory          Unknown
# ...          ...                    ...              ...
# s8803      Movie                 zodiac    David Fincher
# s8804    TV Show            zombie dumb          Unknown
# s8805      Movie             zombieland  Ruben Fleischer
# s8806      Movie                   zoom     Peter Hewitt
# s8807      Movie                 zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# remove duplicate if exists 
df.drop_duplicates(inplace=True)

# %%
# strip white space from other columns
df['country'] = df['country'].str.strip()

# %%
df['duration']
# Out:
# show_id
# s1          90 min
# s2       2 Seasons
# s3        1 Season
# s4        1 Season
# s5       2 Seasons
#            ...
# s8803      158 min
# s8804    2 Seasons
# s8805       88 min
# s8806       88 min
# s8807      111 min
# Name: duration, Length: 8806, dtype: object

# %%
# remove invalid duration 
df[df['duration'].str.contains('[^0-9 Seasonsmin]', na=False)]['duration']
# Out:
# show_id
# s5542    Unknown
# s5795    Unknown
# s5814    Unknown
# Name: duration, dtype: object

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   dick johnson is dead  Kirsten Johnson
# s2       TV Show          blood & water          Unknown
# s3       TV Show              ganglands  Julien Leclercq
# s4       TV Show  jailbirds new orleans          Unknown
# s5       TV Show           kota factory          Unknown
# ...          ...                    ...              ...
# s8803      Movie                 zodiac    David Fincher
# s8804    TV Show            zombie dumb          Unknown
# s8805      Movie             zombieland  Ruben Fleischer
# s8806      Movie                   zoom     Peter Hewitt
# s8807      Movie                 zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# drop dates with unknown 
df = df[df['date_added'] != 'Unknown']

# %%
# convert the date added to date time 
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11956\1446250257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   dick johnson is dead  Kirsten Johnson
# s2       TV Show          blood & water          Unknown
# s3       TV Show              ganglands  Julien Leclercq
# s4       TV Show  jailbirds new orleans          Unknown
# s5       TV Show           kota factory          Unknown
# ...          ...                    ...              ...
# s8803      Movie                 zodiac    David Fincher
# s8804    TV Show            zombie dumb          Unknown
# s8805      Movie             zombieland  Ruben Fleischer
# s8806      Movie                   zoom     Peter Hewitt
# s8807      Movie                 zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Data Transformation

# %%
# calculate range of release for each country 
grouped = df.groupby('country')['title'].apply(len)
print("Number of titles by country:")
print(grouped)
# Out:
# Number of titles by country:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Name: title, Length: 749, dtype: int64

# %%
# calculate the average release year fr each country 
df.groupby('country')['release_year'].mean()
# Out:
# country
# , France, Algeria                                      2014.000000
# , South Korea                                          2021.000000
# Argentina                                              2016.000000
# Argentina, Brazil, France, Poland, Germany, Denmark    2017.000000
# Argentina, Chile                                       2011.500000
#                                                           ...
# Venezuela                                              2017.000000
# Venezuela, Colombia                                    2007.000000
# Vietnam                                                2017.714286
# West Germany                                           1977.000000
# Zimbabwe                                               2017.000000
# Name: release_year, Length: 749, dtype: float64

# %%
# calculate minimum , max, sum, and mean release year for movies and tv shows
df.groupby('type')['release_year'].agg(['min', 'max', 'sum', 'mean'])
# Out:
#           min   max       sum         mean
# type
# Movie    1942  2021  12340434  2013.121370
# TV Show  1925  2021   5376324  2016.625656

# %%
# create a table showing the count of movies and tv shows by country 
df.pivot_table(index='country',columns='type', values='release_year',aggfunc='count')
# Out:
# type                                                Movie  TV Show
# country
# , France, Algeria                                     1.0      NaN
# , South Korea                                         NaN      1.0
# Argentina                                            38.0     18.0
# Argentina, Brazil, France, Poland, Germany, Den...    1.0      NaN
# Argentina, Chile                                      2.0      NaN
# ...                                                   ...      ...
# Venezuela                                             1.0      NaN
# Venezuela, Colombia                                   1.0      NaN
# Vietnam                                               7.0      NaN
# West Germany                                          1.0      NaN
# Zimbabwe                                              1.0      NaN
#
# [749 rows x 2 columns]

# %%
# extract the first genre from the listed_in column
df['primary_genre'] = df['listed_in'].str.split(',').str[0]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11956\2501395284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['primary_genre'] = df['listed_in'].str.split(',').str[0]

# %%
# find the recent movies in the data set 
df[(df['type'] == 'Movie') & (df['release_year'] >= 2020)].head(4)
# Out:
#           type                             title  \
# show_id
# s1       Movie              dick johnson is dead
# s7       Movie  my little pony: a new generation
# s10      Movie                      the starling
# s13      Movie                      je suis karl
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s10                     Theodore Melfi
# s13                Christian Schwochow
#
#                                                       cast  \
# show_id
# s1                                                 Unknown
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                          country date_added  release_year rating duration  \
# show_id
# s1                 United States 2021-09-25          2020  PG-13   90 min
# ...

# %%
# sort titles by release year from newest to oldest
df.sort_values('release_year', ascending=False)
# Out:
#             type                                          title  \
# show_id
# s2       TV Show                                  blood & water
# s8438    TV Show                         the netflix afterparty
# s32      TV Show                             chicago party aunt
# s31        Movie                                ankahi kahaniya
# s26      TV Show                           love on the spectrum
# ...          ...                                            ...
# s8764      Movie                wwii: report from the aleutians
# s8661      Movie  undercover: how to operate behind enemy lines
# s8206      Movie                           the battle of midway
# s7791      Movie                                 prelude to war
# s4251    TV Show              pioneers: first women filmmakers*
#
#                                                   director  \
# show_id
# s2                                                 Unknown
# ...

# %% [markdown]
# ### EDA ->

# %%
# what is the average release year of all the titles in the data 
df['release_year'].mean()
# Out:
# np.float64(2014.1834924965895)

# %%
# what is the median 
df['release_year'].median()
# Out:
# np.float64(2017.0)

# %%
# calculate the std 
result = df['release_year'].std()
print(result)
# Out:
# 8.822691834170545

# %%
# what is the earliest release
df['release_year'].min()
# Out:
# np.int64(1925)

# %%
# what is the latest release year 
df['release_year'].max()
# Out:
# np.int64(2021)

# %%
# how many missing values in each column 
df.count()
# Out:
# type             8796
# title            8796
# director         8796
# cast             8796
# country          8796
# date_added       8708
# release_year     8796
# rating           8796
# duration         8796
# listed_in        8796
# description      8796
# primary_genre    8796
# dtype: int64

# %%
# how many unique values in each column 
df.nunique()
# Out:
# type                2
# title            8791
# director         4529
# cast             7683
# country           749
# date_added       1699
# release_year       74
# rating             16
# duration          221
# listed_in         513
# description      8765
# primary_genre      36
# dtype: int64

# %%
# how many duplicated values existes in each column 
df.apply(lambda x:x.duplicated().sum())
# Out:
# type             8794
# title               5
# director         4267
# cast             1113
# country          8047
# date_added       7096
# release_year     8722
# rating           8780
# duration         8575
# listed_in        8283
# description        31
# primary_genre    8760
# dtype: int64

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   dick johnson is dead  Kirsten Johnson
# s2       TV Show          blood & water          Unknown
# s3       TV Show              ganglands  Julien Leclercq
# s4       TV Show  jailbirds new orleans          Unknown
# s5       TV Show           kota factory          Unknown
# ...          ...                    ...              ...
# s8803      Movie                 zodiac    David Fincher
# s8804    TV Show            zombie dumb          Unknown
# s8805      Movie             zombieland  Ruben Fleischer
# s8806      Movie                   zoom     Peter Hewitt
# s8807      Movie                 zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# how many titles are there for each content type 
df['type'].value_counts()
# Out:
# type
# Movie      6130
# TV Show    2666
# Name: count, dtype: int64

# %%
# for each country 
df['country'].value_counts()
# Out:
# country
# United States                                             2812
# India                                                      972
# Unknown                                                    830
# United Kingdom                                             418
# Japan                                                      244
#                                                           ...
# Germany, Canada, United States                               1
# Denmark, United Kingdom, South Africa, Sweden, Belgium       1
# Serbia, South Korea, Slovenia                                1
# United Kingdom, Spain, Belgium                               1
# South Africa, United States, Japan                           1
# Name: count, Length: 749, dtype: int64

# %%
# find the outliers 
df[['release_year', 'duration']].describe()
# Out:
#        release_year
# count   8796.000000
# mean    2014.183492
# std        8.822692
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   dick johnson is dead  Kirsten Johnson
# s2       TV Show          blood & water          Unknown
# s3       TV Show              ganglands  Julien Leclercq
# s4       TV Show  jailbirds new orleans          Unknown
# s5       TV Show           kota factory          Unknown
# ...          ...                    ...              ...
# s8803      Movie                 zodiac    David Fincher
# s8804    TV Show            zombie dumb          Unknown
# s8805      Movie             zombieland  Ruben Fleischer
# s8806      Movie                   zoom     Peter Hewitt
# s8807      Movie                 zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
plt.figure(figsize=(12, 6))
top_countries = df['country'].value_counts().head(10)
top_countries.plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries by Number of Titles')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.grid(True, axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('bar_titles_by_country.png')
plt.show()
